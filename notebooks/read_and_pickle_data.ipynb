# %% [markdown]
# ## Read in 1 dataset
# - bring only specific columns to save time
# -
# - add year data

# %%
import pandas as pd
import pickle

# %% [markdown]
# #### Columns to keep
#
# - National Provider Identifier -- int64
# - Last Name/Organization Name of the Provider -- object
# - Entity Type of the Provider -- object
# - City of the Provider -- object
# - Zip Code of the Provider -- int64
# - State Code of the Provider -- object
# - Provider Type -- object
# - Place of Service -- object
# - HCPCS Code -- object
# - HCPCS Description -- object
# - Number of Services -- float64
# - Number of Medicare Beneficiaries -- int64
# - Number of Distinct Medicare Beneficiary/Per Day Services -- int64
# - Average Medicare Allowed Amount -- float64
# ADD:  Year (in each df on import)

# %%
cols = ['National Provider Identifier',
        'Last Name/Organization Name of the Provider',
        'Entity Type of the Provider',
        'City of the Provider',
        'Zip Code of the Provider',
        'State Code of the Provider',
        'Provider Type',
        'Place of Service',
        'HCPCS Code',
        'HCPCS Description',
        'Number of Services',
        'Number of Medicare Beneficiaries',
        'Number of Distinct Medicare Beneficiary/Per Day Services',
        'Average Medicare Allowed Amount']

# %% [markdown]
# ### code using chunks
# want to compare processing time vs bringing in full data

# %%
# %%time
#option 1

payment_rows =[]
for chunk in pd.read_csv('../data/1_medicare_data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv', 
                         chunksize = 1000, usecols = cols):
    chunk['year'] = 2017
    payment_rows.append(chunk)
    
df_payments_2017 = pd.concat(payment_rows, ignore_index=True)
# Out:
# Wall time: 2min 28s

# %% [markdown]
# Chunking option 1 took 2 min 20 sec

# %%
# %%time
#option 2

payment_rows =[]
for chunk in pd.read_csv('../data/1_medicare_data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv', 
                         chunksize = 1000, usecols = cols):
    payment_rows.append(chunk)
    
df_payments_2017 = pd.concat(payment_rows, ignore_index=True)
df_payments_2017['year'] = 2017
# Out:
# Wall time: 2min 21s

# %% [markdown]
# chunking option 2 took 1 min 57 sec (and already had a big dataframe saved from option 1 which may have made it slower)

# %%
print(df_payments_2017.shape)
df_payments_2017.head()
# Out:
# (9847443, 15)
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   Entity Type of the Provider City of the Provider Zip Code of the Provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
#   State Code of the Provider      Provider Type Place of Service HCPCS Code  \
# 0                         MD  Internal Medicine                F      99217
# 1                         MD  Internal Medicine                F      99218
# 2                         MD  Internal Medicine                F      99219
# 3                         MD  Internal Medicine                F      99220
# 4                         MD  Internal Medicine                F      99221
#
#                                    HCPCS Description  Number of Services  \
# 0                Hospital observation care discharge               100.0
# 1     Hospital observation care typically 30 minutes                26.0
# 2     Hospital observation care typically 50 minutes                52.0
# 3  Hospital observation care typically 70 minutes...                59.0
# 4  Initial hospital inpatient care, typically 30 ...                16.0
#
#    Number of Medicare Beneficiaries  \
# 0                                96
# 1                                25
# 2                                51
# 3                                59
# 4                                16
#
#    Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                100
# 1                                                 26
# 2                                                 52
# 3                                                 59
# 4                                                 16
#
#    Average Medicare Allowed Amount  year
# 0                        73.398800  2017
# 1                       100.080000  2017
# 2                       136.380000  2017
# 3                       190.363729  2017
# 4                       101.680000  2017

# %% [markdown]
# ### Code without chunks

# %%
# %%time

df_payments_2017 = pd.read_csv('../data/1_medicare_data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv', 
                               usecols = cols)
df_payments_2017['year'] = 2017
# Out:
# <string>:2: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
# Wall time: 30.7 s

# %%
print(df_payments_2017.shape)
df_payments_2017.head()
# Out:
# (9847443, 15)
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   Entity Type of the Provider City of the Provider Zip Code of the Provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
#   State Code of the Provider      Provider Type Place of Service HCPCS Code  \
# 0                         MD  Internal Medicine                F      99217
# 1                         MD  Internal Medicine                F      99218
# 2                         MD  Internal Medicine                F      99219
# 3                         MD  Internal Medicine                F      99220
# 4                         MD  Internal Medicine                F      99221
#
#                                    HCPCS Description  Number of Services  \
# 0                Hospital observation care discharge               100.0
# 1     Hospital observation care typically 30 minutes                26.0
# 2     Hospital observation care typically 50 minutes                52.0
# 3  Hospital observation care typically 70 minutes...                59.0
# 4  Initial hospital inpatient care, typically 30 ...                16.0
#
#    Number of Medicare Beneficiaries  \
# 0                                96
# 1                                25
# 2                                51
# 3                                59
# 4                                16
#
#    Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                100
# 1                                                 26
# 2                                                 52
# 3                                                 59
# 4                                                 16
#
#    Average Medicare Allowed Amount  year
# 0                        73.398800  2017
# 1                       100.080000  2017
# 2                       136.380000  2017
# 3                       190.363729  2017
# 4                       101.680000  2017

# %% [markdown]
# code without chunks took 24.6 seconds!

# %%
#make all lowercase, replace spaces with _, replace '/' with _
df_payments_2017.columns = map(str.lower, df_payments_2017.columns)
df_payments_2017.columns = df_payments_2017.columns.str.replace(" ", "_")
df_payments_2017.columns = df_payments_2017.columns.str.replace("/", "_")

df_payments_2017.head()
# Out:
#    national_provider_identifier last_name_organization_name_of_the_provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   entity_type_of_the_provider city_of_the_provider zip_code_of_the_provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
#   state_code_of_the_provider      provider_type place_of_service hcpcs_code  \
# 0                         MD  Internal Medicine                F      99217
# 1                         MD  Internal Medicine                F      99218
# 2                         MD  Internal Medicine                F      99219
# 3                         MD  Internal Medicine                F      99220
# 4                         MD  Internal Medicine                F      99221
#
#                                    hcpcs_description  number_of_services  \
# 0                Hospital observation care discharge               100.0
# 1     Hospital observation care typically 30 minutes                26.0
# 2     Hospital observation care typically 50 minutes                52.0
# 3  Hospital observation care typically 70 minutes...                59.0
# 4  Initial hospital inpatient care, typically 30 ...                16.0
#
#    number_of_medicare_beneficiaries  \
# 0                                96
# 1                                25
# 2                                51
# 3                                59
# 4                                16
#
#    number_of_distinct_medicare_beneficiary_per_day_services  \
# 0                                                100
# 1                                                 26
# 2                                                 52
# 3                                                 59
# 4                                                 16
#
#    average_medicare_allowed_amount  year
# 0                        73.398800  2017
# 1                       100.080000  2017
# 2                       136.380000  2017
# 3                       190.363729  2017
# 4                       101.680000  2017

# %%
df_payments_2017.to_pickle("../data/1_medicare_data/pickled_files/payments_2017.pkl")

# %% [markdown]
# #### Option 3 is the fastest, using that to bring in other years
# #### 2016

# %%
# %%time

df_payments_2016 = pd.read_csv('../data/1_medicare_data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2016.csv', 
                               usecols = cols)
df_payments_2016['year'] = 2016
# Out:
# <string>:2: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
# Wall time: 32.7 s

# %%
print(df_payments_2016.shape)
df_payments_2016.head()
# Out:
# (9714896, 15)
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   Entity Type of the Provider City of the Provider Zip Code of the Provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
#   State Code of the Provider      Provider Type Place of Service HCPCS Code  \
# 0                         MD  Internal Medicine                F      99217
# 1                         MD  Internal Medicine                F      99219
# 2                         MD  Internal Medicine                F      99220
# 3                         MD  Internal Medicine                F      99221
# 4                         MD  Internal Medicine                F      99222
#
#                                    HCPCS Description  Number of Services  \
# 0                Hospital observation care discharge                57.0
# 1     Hospital observation care typically 50 minutes                38.0
# 2  Hospital observation care typically 70 minutes...                23.0
# 3  Initial hospital inpatient care, typically 30 ...                20.0
# 4  Initial hospital inpatient care, typically 50 ...                96.0
#
#    Number of Medicare Beneficiaries  \
# 0                                55
# 1                                38
# 2                                23
# 3                                20
# 4                                87
#
#    Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                 57
# 1                                                 38
# 2                                                 23
# 3                                                 20
# 4                                                 96
#
#    Average Medicare Allowed Amount  year
# 0                        72.743158  2016
# 1                       135.010000  2016
# 2                       189.239565  2016
# 3                       100.750000  2016
# 4                       136.250000  2016

# %%
#make all lowercase, replace spaces with _, replace '/' with _
df_payments_2016.columns = map(str.lower, df_payments_2016.columns)
df_payments_2016.columns = df_payments_2016.columns.str.replace(" ", "_")
df_payments_2016.columns = df_payments_2016.columns.str.replace("/", "_")

df_payments_2016.head()
# Out:
#    national_provider_identifier last_name_organization_name_of_the_provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   entity_type_of_the_provider city_of_the_provider zip_code_of_the_provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
#   state_code_of_the_provider      provider_type place_of_service hcpcs_code  \
# 0                         MD  Internal Medicine                F      99217
# 1                         MD  Internal Medicine                F      99219
# 2                         MD  Internal Medicine                F      99220
# 3                         MD  Internal Medicine                F      99221
# 4                         MD  Internal Medicine                F      99222
#
#                                    hcpcs_description  number_of_services  \
# 0                Hospital observation care discharge                57.0
# 1     Hospital observation care typically 50 minutes                38.0
# 2  Hospital observation care typically 70 minutes...                23.0
# 3  Initial hospital inpatient care, typically 30 ...                20.0
# 4  Initial hospital inpatient care, typically 50 ...                96.0
#
#    number_of_medicare_beneficiaries  \
# 0                                55
# 1                                38
# 2                                23
# 3                                20
# 4                                87
#
#    number_of_distinct_medicare_beneficiary_per_day_services  \
# 0                                                 57
# 1                                                 38
# 2                                                 23
# 3                                                 20
# 4                                                 96
#
#    average_medicare_allowed_amount  year
# 0                        72.743158  2016
# 1                       135.010000  2016
# 2                       189.239565  2016
# 3                       100.750000  2016
# 4                       136.250000  2016

# %%
df_payments_2016.to_pickle("../data/1_medicare_data/pickled_files/payments_2016.pkl")

# %% [markdown]
# #### 2015

# %%
# %%time

df_payments_2015 = pd.read_csv('../data/1_medicare_data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2015.csv', 
                               usecols = cols)
df_payments_2015['year'] = 2015
# Out:
# <string>:2: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
# Wall time: 33.5 s

# %%
print(df_payments_2015.shape)
df_payments_2015.head()
# Out:
# (9497892, 15)
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   Entity Type of the Provider City of the Provider Zip Code of the Provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
#   State Code of the Provider      Provider Type Place of Service HCPCS Code  \
# 0                         MD  Internal Medicine                F      99217
# 1                         MD  Internal Medicine                F      99219
# 2                         MD  Internal Medicine                F      99221
# 3                         MD  Internal Medicine                F      99222
# 4                         MD  Internal Medicine                F      99223
#
#                                    HCPCS Description  Number of Services  \
# 0                Hospital observation care discharge                23.0
# 1     Hospital observation care typically 50 minutes                18.0
# 2  Initial hospital inpatient care, typically 30 ...                59.0
# 3  Initial hospital inpatient care, typically 50 ...               132.0
# 4  Initial hospital inpatient care, typically 70 ...               220.0
#
#    Number of Medicare Beneficiaries  \
# 0                              23.0
# 1                              18.0
# 2                              58.0
# 3                             130.0
# 4                             215.0
#
#    Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                               23.0
# 1                                               18.0
# 2                                               59.0
# 3                                              132.0
# 4                                              220.0
#
#    Average Medicare Allowed Amount  year
# 0                        72.680000  2015
# 1                       135.850000  2015
# 2                       101.365085  2015
# 3                       139.010455  2015
# 4                       205.185955  2015

# %%
#make all lowercase, replace spaces with _, replace '/' with _
df_payments_2015.columns = map(str.lower, df_payments_2015.columns)
df_payments_2015.columns = df_payments_2015.columns.str.replace(" ", "_")
df_payments_2015.columns = df_payments_2015.columns.str.replace("/", "_")

df_payments_2015.head()
# Out:
#    national_provider_identifier last_name_organization_name_of_the_provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   entity_type_of_the_provider city_of_the_provider zip_code_of_the_provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
#   state_code_of_the_provider      provider_type place_of_service hcpcs_code  \
# 0                         MD  Internal Medicine                F      99217
# 1                         MD  Internal Medicine                F      99219
# 2                         MD  Internal Medicine                F      99221
# 3                         MD  Internal Medicine                F      99222
# 4                         MD  Internal Medicine                F      99223
#
#                                    hcpcs_description  number_of_services  \
# 0                Hospital observation care discharge                23.0
# 1     Hospital observation care typically 50 minutes                18.0
# 2  Initial hospital inpatient care, typically 30 ...                59.0
# 3  Initial hospital inpatient care, typically 50 ...               132.0
# 4  Initial hospital inpatient care, typically 70 ...               220.0
#
#    number_of_medicare_beneficiaries  \
# 0                              23.0
# 1                              18.0
# 2                              58.0
# 3                             130.0
# 4                             215.0
#
#    number_of_distinct_medicare_beneficiary_per_day_services  \
# 0                                               23.0
# 1                                               18.0
# 2                                               59.0
# 3                                              132.0
# 4                                              220.0
#
#    average_medicare_allowed_amount  year
# 0                        72.680000  2015
# 1                       135.850000  2015
# 2                       101.365085  2015
# 3                       139.010455  2015
# 4                       205.185955  2015

# %%
df_payments_2015.dtypes
# Out:
# national_provider_identifier                                  int64
# last_name_organization_name_of_the_provider                  object
# entity_type_of_the_provider                                  object
# city_of_the_provider                                         object
# zip_code_of_the_provider                                     object
# state_code_of_the_provider                                   object
# provider_type                                                object
# place_of_service                                             object
# hcpcs_code                                                   object
# hcpcs_description                                            object
# number_of_services                                          float64
# number_of_medicare_beneficiaries                            float64
# number_of_distinct_medicare_beneficiary_per_day_services    float64
# average_medicare_allowed_amount                             float64
# year                                                          int64
# dtype: object

# %% [markdown]
# #### drop blank row in 2015 file
# identified blank row in data.cms.gov file
# only found in this years data

# %%
df_payments_2015[df_payments_2015.national_provider_identifier == 1]
# Out:
#          national_provider_identifier  \
# 7205022                             1
#
#                last_name_organization_name_of_the_provider  \
# 7205022  CPT copyright 2014 American Medical Associatio...
#
#         entity_type_of_the_provider city_of_the_provider  \
# 7205022                         NaN                  NaN
#
#         zip_code_of_the_provider state_code_of_the_provider provider_type  \
# 7205022                      NaN                        NaN           NaN
#
#         place_of_service hcpcs_code hcpcs_description  number_of_services  \
# 7205022              NaN        NaN               NaN                 NaN
#
#          number_of_medicare_beneficiaries  \
# 7205022                               NaN
#
#          number_of_distinct_medicare_beneficiary_per_day_services  \
# 7205022                                                NaN
#
#          average_medicare_allowed_amount  year
# 7205022                              NaN  2015

# %%
df_payments_2015 = df_payments_2015.drop(labels = 7205022)

# %%
df_payments_2015.to_pickle("../data/1_medicare_data/pickled_files/payments_2015.pkl")

# %% [markdown]
# ### Combine 3 years into one dataframe, pickle that

# %%
df_payments_combined = pd.concat([df_payments_2015, df_payments_2016, df_payments_2017], ignore_index= True)

# %%
df_payments_combined.head()
# Out:
#    national_provider_identifier last_name_organization_name_of_the_provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   entity_type_of_the_provider city_of_the_provider zip_code_of_the_provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
#   state_code_of_the_provider      provider_type place_of_service hcpcs_code  \
# 0                         MD  Internal Medicine                F      99217
# 1                         MD  Internal Medicine                F      99219
# 2                         MD  Internal Medicine                F      99221
# 3                         MD  Internal Medicine                F      99222
# 4                         MD  Internal Medicine                F      99223
#
#                                    hcpcs_description  number_of_services  \
# 0                Hospital observation care discharge                23.0
# 1     Hospital observation care typically 50 minutes                18.0
# 2  Initial hospital inpatient care, typically 30 ...                59.0
# 3  Initial hospital inpatient care, typically 50 ...               132.0
# 4  Initial hospital inpatient care, typically 70 ...               220.0
#
#    number_of_medicare_beneficiaries  \
# 0                              23.0
# 1                              18.0
# 2                              58.0
# 3                             130.0
# 4                             215.0
#
#    number_of_distinct_medicare_beneficiary_per_day_services  \
# 0                                               23.0
# 1                                               18.0
# 2                                               59.0
# 3                                              132.0
# 4                                              220.0
#
#    average_medicare_allowed_amount  year
# 0                        72.680000  2015
# 1                       135.850000  2015
# 2                       101.365085  2015
# 3                       139.010455  2015
# 4                       205.185955  2015

# %%
df_payments_combined.to_pickle("../data/1_medicare_data/pickled_files/payments_combined.pkl")
