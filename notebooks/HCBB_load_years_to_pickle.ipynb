# %%
import pandas as pd
import pickle

# %%
# %%time
# option 2

cols = ['National Provider Identifier',
        'Last Name/Organization Name of the Provider',
        'Entity Type of the Provider',
        'City of the Provider',
        'Zip Code of the Provider',
        'State Code of the Provider',
        'Provider Type',
        'HCPCS Code',
        'HCPCS Description',
        'Place of Service',
        'Number of Services',
        'Number of Medicare Beneficiaries',
        'Number of Distinct Medicare Beneficiary/Per Day Services',
        'Average Medicare Allowed Amount']

df_payments_2017 = pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2015.csv', 
                               usecols = cols)
df_payments_2017['year'] = 2015
# Out:
# Wall time: 25 s

# %%
#load all three csv files and add year column
# need more work on this code
'''%%time
# option 2

cols = ['National Provider Identifier',
        'Last Name/Organization Name of the Provider',
        'Entity Type of the Provider',
        'City of the Provider',
        'Zip Code of the Provider',
        'State Code of the Provider',
        'Provider Type',
        'Place of Service',
        'Number of Services',
        'Number of Medicare Beneficiaries',
        'Number of Distinct Medicare Beneficiary/Per Day Services',
        'Average Medicare Allowed Amount']
years=['CY2017','CY2016','CY2015']

for year in years:
    path ='../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_%.csv' % year
    frame = pd.read_csv(path, usecols = cols)

   # frame['year'] = year
    pieces.append(frame)

# Concatenates everything into a single Dataframe
names = pd.concat(pieces, ignore_index=True)'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# TypeError: %c requires int or char

# %%
print(df_payments_2017.shape)
# Out:
# (9497892, 15)

# %%
df_payments_2017.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   Entity Type of the Provider City of the Provider Zip Code of the Provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
# ...

# %%
#turn columns names to lower case and replace spaces and '/' with '_'
df_payments_2017.columns = map(str.lower, df_payments_2017.columns)
df_payments_2017.columns = df_payments_2017.columns.str.replace(' ', '_')
df_payments_2017.columns = df_payments_2017.columns.str.replace('/', '_')
df_payments_2017.head()
# Out:
#    national_provider_identifier last_name_organization_name_of_the_provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   entity_type_of_the_provider city_of_the_provider zip_code_of_the_provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
# ...

# %%
#df_payments_2017 = df_payments_2017.drop(labels = 7205022)

# %%
#df_payments_2017[df_payments_2017.national_provider_identifier == 1]

# %%
#save it as pkl
df_payments_2017.to_pickle("../data/df_payments_2015.pkl")
