# %%
import pandas as pd
import pickle
import xlrd

# %%
# %%time

outpatient_charge_df = pd.DataFrame()
chunk_nbr = 1

for chunk in pd.read_csv('../class_data/Provider_Outpatient_Hospital_Charge_Data_by_APC__CY2017.csv', chunksize = 1000):
    if chunk_nbr == 1:
        outpatient_charge_df = outpatient_charge_df.append(chunk)
        chunk_nbr += 1
    else: break
outpatient_charge_df.head()
# Out:
# CPU times: user 15.3 ms, sys: 4.12 ms, total: 19.4 ms
# Wall time: 19.3 ms
#    Provider_ID                     Provider_Name Provider_Street_Address  \
# 0        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 1        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 2        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 3        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 4        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   Provider_City Provider_State  Provider_Zip_Code Provider_HRR   APC  \
# 0        Dothan             AL              36301  AL - Dothan  5072
# 1        Dothan             AL              36301  AL - Dothan  5073
# 2        Dothan             AL              36301  AL - Dothan  5091
# 3        Dothan             AL              36301  AL - Dothan  5092
# 4        Dothan             AL              36301  AL - Dothan  5112
#
# ...

# %%
outpatient_charge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Provider_ID                      1000 non-null   int64
#  1   Provider_Name                    1000 non-null   object
#  2   Provider_Street_Address          1000 non-null   object
#  3   Provider_City                    1000 non-null   object
#  4   Provider_State                   1000 non-null   object
#  5   Provider_Zip_Code                1000 non-null   int64
#  6   Provider_HRR                     1000 non-null   object
#  7   APC                              1000 non-null   int64
#  8   APC_Desc                         1000 non-null   object
#  9   Beneficiaries                    989 non-null    float64
#  10  CAPC_Services                    1000 non-null   int64
#  11  Average_Total_Submitted_Charges  1000 non-null   float64
# ...

# %%
outpatient_charge_df.to_pickle("../class_data/outpatient_charge.pkl")

# %%
# %%time

outpatient_charge_df = pd.read_pickle("../class_data/outpatient_charge.pkl")
# Out:
# CPU times: user 2.02 ms, sys: 1.26 ms, total: 3.27 ms
# Wall time: 2.27 ms

# %%
outpatient_charge_df.head()
# Out:
#    Provider_ID                     Provider_Name Provider_Street_Address  \
# 0        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 1        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 2        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 3        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 4        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   Provider_City Provider_State  Provider_Zip_Code Provider_HRR   APC  \
# 0        Dothan             AL              36301  AL - Dothan  5072
# 1        Dothan             AL              36301  AL - Dothan  5073
# 2        Dothan             AL              36301  AL - Dothan  5091
# 3        Dothan             AL              36301  AL - Dothan  5092
# 4        Dothan             AL              36301  AL - Dothan  5112
#
#                                             APC_Desc  Beneficiaries  \
# ...

# %%
zip_codes = pd.read_excel('../class_data/ZIP_CBSA_032020.xlsx')

# %%
zip_codes.head()
# Out:
#    ZIP   CBSA  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 0  501  35620        0.0        1.0        0.0        1.0
# 1  601  38660        1.0        1.0        1.0        1.0
# 2  602  10380        1.0        1.0        1.0        1.0
# 3  603  10380        1.0        1.0        1.0        1.0
# 4  604  10380        1.0        1.0        1.0        1.0

# %%
addendum_df = pd.read_excel('../class_data/2020_january_web_addendum_b.12312019.xlsx')

# %%
addendum_df.head()
# Out:
#    Unnamed: 0 Addendum B.-Final OPPS Payment by HCPCS Code for CY 2020  \
# 0         NaN  CPT codes and descriptions only are copyright ...
# 1  HCPCS Code                                   Short Descriptor
# 2       00100                              Anesth salivary gland
# 3       00102                         Anesth repair of cleft lip
# 4       00103                              Anesth blepharoplasty
#
#   Unnamed: 2 Unnamed: 3       Unnamed: 4     Unnamed: 5  \
# 0        NaN        NaN              NaN            NaN
# 1         SI       APC   Relative Weight  Payment Rate
# 2          N        NaN              NaN            NaN
# 3          N        NaN              NaN            NaN
# 4          N        NaN              NaN            NaN
#
#                        Unnamed: 6                     Unnamed: 7  \
# 0                             NaN                            NaN
# 1  National Unadjusted Copayment   Minimum Unadjusted Copayment
# ...
