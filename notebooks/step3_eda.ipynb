# %% [markdown]
# # EDA on Medicare data 2015-2017

# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Read in Combined DataFrame
#
# This combined df has already eliminted the one irrelevant row from 2015, and has added a column for payment_type (Doctor Only, Facility Only, Doctor & Facility).

# %%
df_payments_combined = pd.read_pickle('../data/payments_combined.pkl')
print(df_payments_combined.shape)
df_payments_combined.head()
# Out:
# (29060230, 16)
#    national_provider_identifier last_name_organization_name_of_the_provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   entity_type_of_the_provider city_of_the_provider zip_code_of_the_provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
#   state_code_of_the_provider      provider_type place_of_service hcpcs_code  \
# 0                         MD  Internal Medicine                F      99217
# 1                         MD  Internal Medicine                F      99219
# 2                         MD  Internal Medicine                F      99221
# 3                         MD  Internal Medicine                F      99222
# 4                         MD  Internal Medicine                F      99223
#
#                                    hcpcs_description  number_of_services  \
# 0                Hospital observation care discharge                23.0
# 1     Hospital observation care typically 50 minutes                18.0
# 2  Initial hospital inpatient care, typically 30 ...                59.0
# 3  Initial hospital inpatient care, typically 50 ...               132.0
# 4  Initial hospital inpatient care, typically 70 ...               220.0
#
#    number_of_medicare_beneficiaries  \
# 0                              23.0
# 1                              18.0
# 2                              58.0
# 3                             130.0
# 4                             215.0
#
#    number_of_distinct_medicare_beneficiary_per_day_services  \
# 0                                               23.0
# 1                                               18.0
# 2                                               59.0
# 3                                              132.0
# 4                                              220.0
#
#    average_medicare_allowed_amount  year payment_type
# 0                        72.680000  2015  Doctor Only
# 1                       135.850000  2015  Doctor Only
# 2                       101.365085  2015  Doctor Only
# 3                       139.010455  2015  Doctor Only
# 4                       205.185955  2015  Doctor Only

# %% [markdown]
# # EDA of combined data

# %%
df_payments_combined.shape
# Out:
# (29060230, 16)

# %%
df_payments_combined.columns
# Out:
# Index(['national_provider_identifier',
#        'last_name_organization_name_of_the_provider',
#        'entity_type_of_the_provider', 'city_of_the_provider',
#        'zip_code_of_the_provider', 'state_code_of_the_provider',
#        'provider_type', 'place_of_service', 'hcpcs_code', 'hcpcs_description',
#        'number_of_services', 'number_of_medicare_beneficiaries',
#        'number_of_distinct_medicare_beneficiary_per_day_services',
#        'average_medicare_allowed_amount', 'year', 'payment_type'],
#       dtype='object')

# %%
df_payments_combined.head()
# Out:
#    national_provider_identifier last_name_organization_name_of_the_provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   entity_type_of_the_provider city_of_the_provider zip_code_of_the_provider  \
# 0                           I           CUMBERLAND                215021854
# 1                           I           CUMBERLAND                215021854
# 2                           I           CUMBERLAND                215021854
# 3                           I           CUMBERLAND                215021854
# 4                           I           CUMBERLAND                215021854
#
#   state_code_of_the_provider      provider_type place_of_service hcpcs_code  \
# 0                         MD  Internal Medicine                F      99217
# 1                         MD  Internal Medicine                F      99219
# 2                         MD  Internal Medicine                F      99221
# 3                         MD  Internal Medicine                F      99222
# 4                         MD  Internal Medicine                F      99223
#
#                                    hcpcs_description  number_of_services  \
# 0                Hospital observation care discharge                23.0
# 1     Hospital observation care typically 50 minutes                18.0
# 2  Initial hospital inpatient care, typically 30 ...                59.0
# 3  Initial hospital inpatient care, typically 50 ...               132.0
# 4  Initial hospital inpatient care, typically 70 ...               220.0
#
#    number_of_medicare_beneficiaries  \
# 0                              23.0
# 1                              18.0
# 2                              58.0
# 3                             130.0
# 4                             215.0
#
#    number_of_distinct_medicare_beneficiary_per_day_services  \
# 0                                               23.0
# 1                                               18.0
# 2                                               59.0
# 3                                              132.0
# 4                                              220.0
#
#    average_medicare_allowed_amount  year payment_type
# 0                        72.680000  2015  Doctor Only
# 1                       135.850000  2015  Doctor Only
# 2                       101.365085  2015  Doctor Only
# 3                       139.010455  2015  Doctor Only
# 4                       205.185955  2015  Doctor Only

# %%
df_payments_combined.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29060230 entries, 0 to 29060230
# Data columns (total 16 columns):
#  #   Column                                                    Non-Null Count     Dtype
# ---  ------                                                    --------------     -----
#  0   national_provider_identifier                              29060230 non-null  int64
#  1   last_name_organization_name_of_the_provider               29059803 non-null  object
#  2   entity_type_of_the_provider                               29060230 non-null  object
#  3   city_of_the_provider                                      29060225 non-null  object
#  4   zip_code_of_the_provider                                  29060226 non-null  object
#  5   state_code_of_the_provider                                29060230 non-null  object
#  6   provider_type                                             29060230 non-null  object
#  7   place_of_service                                          29060230 non-null  object
#  8   hcpcs_code                                                29060230 non-null  object
#  9   hcpcs_description                                         29060230 non-null  object
#  10  number_of_services                                        29060230 non-null  float64
#  11  number_of_medicare_beneficiaries                          29060230 non-null  float64
#  12  number_of_distinct_medicare_beneficiary_per_day_services  29060230 non-null  float64
#  13  average_medicare_allowed_amount                           29060230 non-null  float64
#  14  year                                                      29060230 non-null  int64
#  15  payment_type                                              29060230 non-null  object
# dtypes: float64(4), int64(2), object(10)
# memory usage: 3.7+ GB

# %%
# look at null values

df_payments_combined.isnull().sum()

# 427 null values for provider name. When we looked at this in the data visualizer on the Medicare website,
# these rows had first names (a column we chose to drop from our dataset) and all other pertinent values.
# Since the NPI is unique to each provider, we determined that a null value in the provider name column was not
# an impediment to analysis.
# Out:
# national_provider_identifier                                  0
# last_name_organization_name_of_the_provider                 427
# entity_type_of_the_provider                                   0
# city_of_the_provider                                          5
# zip_code_of_the_provider                                      4
# state_code_of_the_provider                                    0
# provider_type                                                 0
# place_of_service                                              0
# hcpcs_code                                                    0
# hcpcs_description                                             0
# number_of_services                                            0
# number_of_medicare_beneficiaries                              0
# number_of_distinct_medicare_beneficiary_per_day_services      0
# average_medicare_allowed_amount                               0
# year                                                          0
# payment_type                                                  0
# dtype: int64

# %%
# number of unique HCPCS codes used

count_of_codes = df_payments_combined.hcpcs_code.nunique()
print("There are", count_of_codes, "unique HCPCS codes in 2015-2017")
# Out:
# There are 6763 unique HCPCS codes in 2015-2017

# %%
# number_of_services stats 
# min 2.4 (how is this not a round number?)
# max 7,195,536

# note: mean is 246 and median is 44

df_payments_combined.number_of_services.describe()
# Out:
# count    2.906023e+07
# mean     2.460806e+02
# std      4.828521e+03
# min      2.400000e+00
# 25%      2.100000e+01
# 50%      4.400000e+01
# 75%      1.190000e+02
# max      7.195536e+06
# Name: number_of_services, dtype: float64

# %%
df_payments_combined.number_of_medicare_beneficiaries.describe()
# Out:
# count    2.906023e+07
# mean     8.916477e+01
# std      1.158662e+03
# min      1.100000e+01
# 25%      1.700000e+01
# 50%      3.300000e+01
# 75%      7.600000e+01
# max      7.928730e+05
# Name: number_of_medicare_beneficiaries, dtype: float64

# %%
# mean 143.7782
# median 41

df_payments_combined.number_of_distinct_medicare_beneficiary_per_day_services.describe()
# Out:
# count    2.906023e+07
# mean     1.437782e+02
# std      2.222082e+03
# min      1.100000e+01
# 25%      2.000000e+01
# 50%      4.100000e+01
# 75%      1.080000e+02
# max      2.180422e+06
# Name: number_of_distinct_medicare_beneficiary_per_day_services, dtype: float64

# %%
# mean 100.43
# median 63.99

# min 0.0000603 (check, this doesn't seem valid, although the numbers in this column are averages for a provider
# for a single HCPCS code so maybe it is)

df_payments_combined.average_medicare_allowed_amount.describe()
# Out:
# count    2.906023e+07
# mean     1.004310e+02
# std      2.578002e+02
# min      6.035380e-05
# 25%      2.378000e+01
# 50%      6.399000e+01
# 75%      1.136400e+02
# max      5.668435e+04
# Name: average_medicare_allowed_amount, dtype: float64

# %% [markdown]
# Significant difference between mean and median in the stats for the measures above.

# %% [markdown]
# # Creating new df showing average payment by year, then by payment type, then by HCPCS code. (Code from Nicole)

# %%
df_avg_pmt = df_payments_combined.groupby(['year',
                                           'payment_type',
                                           'hcpcs_code']).average_medicare_allowed_amount.mean().to_frame()

# %%
df_avg_pmt = df_avg_pmt.reset_index()
df_avg_pmt.head()
# Out:
#    index  year       payment_type hcpcs_code  average_medicare_allowed_amount
# 0      0  2015  Doctor & Facility      00103                       255.076212
# 1      1  2015  Doctor & Facility      00104                       111.614526
# 2      2  2015  Doctor & Facility      00140                       139.047955
# 3      3  2015  Doctor & Facility      00142                       102.570003
# 4      4  2015  Doctor & Facility      00160                       211.812813

# %%
df_avg_pmt.shape
# Out:
# (28879, 5)

# %%
df_avg_pmt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28879 entries, 0 to 28878
# Data columns (total 5 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   index                            28879 non-null  int64
#  1   year                             28879 non-null  int64
#  2   payment_type                     28879 non-null  object
#  3   hcpcs_code                       28879 non-null  object
#  4   average_medicare_allowed_amount  28879 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.1+ MB

# %%
df_med_services_day = df_payments_combined.groupby(['year',
                                                    'hcpcs_code']).number_of_distinct_medicare_beneficiary_per_day_services.mean().to_frame().reset_index()

df_med_services_day.head()
# Out:
#    year hcpcs_code  number_of_distinct_medicare_beneficiary_per_day_services
# 0  2015      00100                                          15.000000
# 1  2015      00102                                          26.000000
# 2  2015      00103                                          29.192544
# 3  2015      00104                                          48.568561
# 4  2015      00120                                          22.018182

# %%
# still seeing wide variance between mean and median
# examine outliers

df_avg_pmt.describe()
# Out:
#               index         year  average_medicare_allowed_amount
# count  28879.000000  28879.00000                     28879.000000
# mean   14439.000000   2016.00980                       379.808995
# std     8336.793548      0.81578                      1192.709320
# min        0.000000   2015.00000                         0.010000
# 25%     7219.500000   2015.00000                        33.868522
# 50%    14439.000000   2016.00000                       124.781988
# 75%    21658.500000   2017.00000                       388.973461
# max    28878.000000   2017.00000                     39279.086545

# %%
# still seeing wide variance between mean and median 
# examine outliers

df_med_services_day.describe()
# Out:
#                year  number_of_distinct_medicare_beneficiary_per_day_services
# count  18053.000000                                       1.805300e+04
# mean    2016.003601                                       5.378346e+02
# std        0.816364                                       2.605081e+04
# min     2015.000000                                       1.100000e+01
# 25%     2015.000000                                       1.825000e+01
# 50%     2016.000000                                       2.998214e+01
# 75%     2017.000000                                       7.002296e+01
# max     2017.000000                                       2.180422e+06

# %% [markdown]
# # Pivot dataframe

# %%
pivot_index = ['national_provider_identifier',
               'entity_type_of_the_provider', 
               'place_of_service',
               'payment_type',
               'provider_type',
               'hcpcs_code',
               'hcpcs_description',
               'zip_code_of_the_provider', 
               'state_code_of_the_provider']

pivot_cols = ['year']

# %%
# %%time
df_pmt_pvt = df_payments_combined.pivot_table(index = pivot_index, 
                                              columns = pivot_cols, 
                                              values = 'average_medicare_allowed_amount', 
                                              aggfunc=np.mean)

df_pmt_pvt = df_pmt_pvt.reset_index()
# Out:
# CPU times: user 1min 31s, sys: 27.2 s, total: 1min 58s
# Wall time: 2min

# %%
print(df_pmt_pvt.shape)
df_pmt_pvt.head()
# Out:
# (16132777, 12)
# year  national_provider_identifier entity_type_of_the_provider  \
# 0                       1003000126                           I
# 1                       1003000126                           I
# 2                       1003000126                           I
# 3                       1003000126                           I
# 4                       1003000126                           I
#
# year place_of_service payment_type      provider_type hcpcs_code  \
# 0                   F  Doctor Only  Internal Medicine      99217
# 1                   F  Doctor Only  Internal Medicine      99218
# 2                   F  Doctor Only  Internal Medicine      99219
# 3                   F  Doctor Only  Internal Medicine      99220
# 4                   F  Doctor Only  Internal Medicine      99221
#
# year                                  hcpcs_description  \
# 0                   Hospital observation care discharge
# 1        Hospital observation care typically 30 minutes
# 2        Hospital observation care typically 50 minutes
# 3     Hospital observation care typically 70 minutes...
# 4     Initial hospital inpatient care, typically 30 ...
#
# year zip_code_of_the_provider state_code_of_the_provider        2015  \
# 0                   215021854                         MD   72.680000
# 1                   215021854                         MD         NaN
# 2                   215021854                         MD  135.850000
# 3                   215021854                         MD         NaN
# 4                   215021854                         MD  101.365085
#
# year        2016        2017
# 0      72.743158   73.398800
# 1            NaN  100.080000
# 2     135.010000  136.380000
# 3     189.239565  190.363729
# 4     100.750000  101.680000

# %%
# %%time
df_bpd_pvt = df_payments_combined.pivot_table(index = pivot_index, 
                                              columns = pivot_cols, 
                                              values = 'number_of_distinct_medicare_beneficiary_per_day_services', 
                                              aggfunc=np.mean)

df_bpd_pvt = df_bpd_pvt.reset_index()
# Out:
# CPU times: user 1min 31s, sys: 31.8 s, total: 2min 3s
# Wall time: 2min 6s

# %%
print(df_bpd_pvt.shape)
df_bpd_pvt.head()
# Out:
# (16132777, 12)
# year  national_provider_identifier entity_type_of_the_provider  \
# 0                       1003000126                           I
# 1                       1003000126                           I
# 2                       1003000126                           I
# 3                       1003000126                           I
# 4                       1003000126                           I
#
# year place_of_service payment_type      provider_type hcpcs_code  \
# 0                   F  Doctor Only  Internal Medicine      99217
# 1                   F  Doctor Only  Internal Medicine      99218
# 2                   F  Doctor Only  Internal Medicine      99219
# 3                   F  Doctor Only  Internal Medicine      99220
# 4                   F  Doctor Only  Internal Medicine      99221
#
# year                                  hcpcs_description  \
# 0                   Hospital observation care discharge
# 1        Hospital observation care typically 30 minutes
# 2        Hospital observation care typically 50 minutes
# 3     Hospital observation care typically 70 minutes...
# 4     Initial hospital inpatient care, typically 30 ...
#
# year zip_code_of_the_provider state_code_of_the_provider  2015  2016   2017
# 0                   215021854                         MD  23.0  57.0  100.0
# 1                   215021854                         MD   NaN   NaN   26.0
# 2                   215021854                         MD  18.0  38.0   52.0
# 3                   215021854                         MD   NaN  23.0   59.0
# 4                   215021854                         MD  59.0  20.0   16.0

# %%
df_pmt_pvt.describe()
# Out:
# year   national_provider_identifier          2015          2016          2017
# count                  1.613278e+07  9.497891e+06  9.714894e+06  9.847441e+06
# mean                   1.499742e+09  9.947302e+01  1.001832e+02  1.015993e+02
# std                    2.877722e+08  2.384662e+02  2.563474e+02  2.764955e+02
# min                    1.003000e+09  1.026528e-04  1.059603e-04  6.035380e-05
# 25%                    1.245694e+09  2.315282e+01  2.376625e+01  2.426084e+01
# 50%                    1.497968e+09  6.288879e+01  6.409979e+01  6.499766e+01
# 75%                    1.740673e+09  1.138798e+02  1.135600e+02  1.135044e+02
# max                    1.993000e+09  5.260147e+04  5.060338e+04  5.668435e+04

# %%
df_pmt_pvt.columns
# Out:
# Index(['national_provider_identifier',  'entity_type_of_the_provider',
#                    'place_of_service',                 'payment_type',
#                       'provider_type',                   'hcpcs_code',
#                   'hcpcs_description',     'zip_code_of_the_provider',
#          'state_code_of_the_provider',                           2015,
#                                  2016,                           2017],
#       dtype='object', name='year')

# %%
df_pmt_pvt.shape
# Out:
# (16132777, 12)

# %%
df_pmt_pvt.to_pickle('../data/df_pmt_pvt.pkl')

# %%
df_bpd_pvt.to_pickle('../data/df_bpd_pvt.pkl')

# %%
df_pmt_pvt_group = df_pmt_pvt.groupby(['payment_type', 
                                       'hcpcs_code'])

df_pmt_pvt_group.head()
# Out:
# year      national_provider_identifier entity_type_of_the_provider  \
# 0                           1003000126                           I
# 1                           1003000126                           I
# 2                           1003000126                           I
# 3                           1003000126                           I
# 4                           1003000126                           I
# ...                                ...                         ...
# 16106962                    1992900526                           I
# 16123307                    1992961270                           I
# 16125064                    1992965974                           I
# 16126960                    1992970230                           O
# 16129655                    1992984512                           I
#
# year     place_of_service       payment_type               provider_type  \
# 0                       F        Doctor Only           Internal Medicine
# 1                       F        Doctor Only           Internal Medicine
# 2                       F        Doctor Only           Internal Medicine
# 3                       F        Doctor Only           Internal Medicine
# 4                       F        Doctor Only           Internal Medicine
# ...                   ...                ...                         ...
# 16106962                F        Doctor Only                     Urology
# 16123307                F        Doctor Only             Cardiac Surgery
# 16125064                O  Doctor & Facility             General Surgery
# 16126960                F      Facility Only  Ambulatory Surgical Center
# 16129655                O  Doctor & Facility        Diagnostic Radiology
#
# year     hcpcs_code                                  hcpcs_description  \
# 0             99217                Hospital observation care discharge
# 1             99218     Hospital observation care typically 30 minutes
# 2             99219     Hospital observation care typically 50 minutes
# 3             99220  Hospital observation care typically 70 minutes...
# 4             99221  Initial hospital inpatient care, typically 30 ...
# ...             ...                                                ...
# 16106962      52334  Insertion of guide wire through kidney into ur...
# 16123307      35521  Bypass of diseased or blocked artery (arm to u...
# 16125064      64630   Destruction of pudendal (external genital) nerve
# 16126960      62287  Aspiration of lower spine disc, accessed throu...
# 16129655      78102                Imaging of bone marrow limited area
#
# year     zip_code_of_the_provider state_code_of_the_provider        2015  \
# 0                       215021854                         MD   72.680000
# 1                       215021854                         MD         NaN
# 2                       215021854                         MD  135.850000
# 3                       215021854                         MD         NaN
# 4                       215021854                         MD  101.365085
# ...                           ...                        ...         ...
# 16106962                200162618                         DC  135.136316
# 16123307                937202693                         CA  660.248182
# 16125064                112235502                         NY  223.511613
# 16126960                339195193                         FL         NaN
# 16129655                341086732                         FL         NaN
#
# year             2016         2017
# 0           72.743158    73.398800
# 1                 NaN   100.080000
# 2          135.010000   136.380000
# 3          189.239565   190.363729
# 4          100.750000   101.680000
# ...               ...          ...
# 16106962          NaN          NaN
# 16123307          NaN          NaN
# 16125064   234.163636   210.968696
# 16126960  1847.770000  1831.410000
# 16129655   183.060000          NaN
#
# [45047 rows x 12 columns]

# %%
df_pmt_pvt_group.hcpcs_code.value_counts()
# Out:
# payment_type       hcpcs_code  hcpcs_code
# Doctor & Facility  0008M       0008M           7
#                    00103       00103         124
#                    00104       00104          59
#                    0010M       0010M           1
#                    00120       00120           4
#                                             ...
# Facility Only      Q4172       Q4172          10
#                    Q9968       Q9968           6
#                    R0070       R0070         121
#                    R0075       R0075          78
#                    V2785       V2785         317
# Name: hcpcs_code, Length: 11179, dtype: int64

# %%
df_pmt_pvt_group_diff = df_pmt_pvt_group
df_pmt_pvt_group_diff.head()
# Out:
# year      national_provider_identifier entity_type_of_the_provider  \
# 0                           1003000126                           I
# 1                           1003000126                           I
# 2                           1003000126                           I
# 3                           1003000126                           I
# 4                           1003000126                           I
# ...                                ...                         ...
# 16106962                    1992900526                           I
# 16123307                    1992961270                           I
# 16125064                    1992965974                           I
# 16126960                    1992970230                           O
# 16129655                    1992984512                           I
#
# year     place_of_service       payment_type               provider_type  \
# 0                       F        Doctor Only           Internal Medicine
# 1                       F        Doctor Only           Internal Medicine
# 2                       F        Doctor Only           Internal Medicine
# 3                       F        Doctor Only           Internal Medicine
# 4                       F        Doctor Only           Internal Medicine
# ...                   ...                ...                         ...
# 16106962                F        Doctor Only                     Urology
# 16123307                F        Doctor Only             Cardiac Surgery
# 16125064                O  Doctor & Facility             General Surgery
# 16126960                F      Facility Only  Ambulatory Surgical Center
# 16129655                O  Doctor & Facility        Diagnostic Radiology
#
# year     hcpcs_code                                  hcpcs_description  \
# 0             99217                Hospital observation care discharge
# 1             99218     Hospital observation care typically 30 minutes
# 2             99219     Hospital observation care typically 50 minutes
# 3             99220  Hospital observation care typically 70 minutes...
# 4             99221  Initial hospital inpatient care, typically 30 ...
# ...             ...                                                ...
# 16106962      52334  Insertion of guide wire through kidney into ur...
# 16123307      35521  Bypass of diseased or blocked artery (arm to u...
# 16125064      64630   Destruction of pudendal (external genital) nerve
# 16126960      62287  Aspiration of lower spine disc, accessed throu...
# 16129655      78102                Imaging of bone marrow limited area
#
# year     zip_code_of_the_provider state_code_of_the_provider        2015  \
# 0                       215021854                         MD   72.680000
# 1                       215021854                         MD         NaN
# 2                       215021854                         MD  135.850000
# 3                       215021854                         MD         NaN
# 4                       215021854                         MD  101.365085
# ...                           ...                        ...         ...
# 16106962                200162618                         DC  135.136316
# 16123307                937202693                         CA  660.248182
# 16125064                112235502                         NY  223.511613
# 16126960                339195193                         FL         NaN
# 16129655                341086732                         FL         NaN
#
# year             2016         2017
# 0           72.743158    73.398800
# 1                 NaN   100.080000
# 2          135.010000   136.380000
# 3          189.239565   190.363729
# 4          100.750000   101.680000
# ...               ...          ...
# 16106962          NaN          NaN
# 16123307          NaN          NaN
# 16125064   234.163636   210.968696
# 16126960  1847.770000  1831.410000
# 16129655   183.060000          NaN
#
# [45047 rows x 12 columns]

# %%
# not working - pivot dataframe is wierd about grouping/aggregating

df_pmt_pvt__group_diff['pmt_diff_amt'] = df_pmt_pvt_group_diff[2017] - df_pmt_pvt_group_diff[2015]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-11ff9be529a6> in <module>
# ----> 1 df_pmt_pvt__group_diff['pmt_diff_amt'] = df_pmt_pvt_group_diff[2017] - df_pmt_pvt_group_diff[2015]
#
# TypeError: unsupported operand type(s) for -: 'SeriesGroupBy' and 'SeriesGroupBy'

# %%
df_pmt_pvt.to_csv('../data/df_pmt_pvt.csv')

# %%
df_payments_combined.to_csv('../data/df_payments_combined.csv')
