# %%
import pandas as pd
import pickle

# %% [markdown]
# #### [The medicare provider utilization and payment data](https://data.cms.gov/Medicare-Physician-Supplier/Medicare-Provider-Utilization-and-Payment-Data-Phy/fs4p-t5eq/data) is a largish file (a little over 2 GB)   with 1,242,756 rows
# Depending on your computer's resources you can:
#  - read it in, make it smaller, and pickle it for faster loading next time
#      - remove unwanted columns
#      - convert as columns that are of datatype *object* to datetimes or numeric types as possible
#  - read it in in chunks

# %% [markdown]
# #### Let's grab a single chunk of 1000 records and look at it

# %%
# %%time

payment_df = pd.DataFrame()
chunk_nbr = 1

for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv', chunksize = 1000):
    if chunk_nbr == 1:
        payment_df = payment_df.append(chunk)
        chunk_nbr += 1
    else: break
payment_df.head()
# Out:
# CPU times: user 21.3 ms, sys: 3.86 ms, total: 25.2 ms
# Wall time: 25 ms
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                    ARDALAN                            NaN
# 2                    ARDALAN                            NaN
# 3                    ARDALAN                            NaN
# 4                    ARDALAN                            NaN
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# 1                        M.D.                      M
# 2                        M.D.                      M
# 3                        M.D.                      M
# 4                        M.D.                      M
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I                     900 SETON DR
# 1                           I                     900 SETON DR
# 2                           I                     900 SETON DR
# 3                           I                     900 SETON DR
# 4                           I                     900 SETON DR
#
#   Street Address 2 of the Provider City of the Provider  ...  HCPCS Code  \
# 0                              NaN           CUMBERLAND  ...       99217
# 1                              NaN           CUMBERLAND  ...       99218
# 2                              NaN           CUMBERLAND  ...       99219
# 3                              NaN           CUMBERLAND  ...       99220
# 4                              NaN           CUMBERLAND  ...       99221
#
#                                    HCPCS Description HCPCS Drug Indicator  \
# 0                Hospital observation care discharge                    N
# 1     Hospital observation care typically 30 minutes                    N
# 2     Hospital observation care typically 50 minutes                    N
# 3  Hospital observation care typically 70 minutes...                    N
# 4  Initial hospital inpatient care, typically 30 ...                    N
#
#   Number of Services Number of Medicare Beneficiaries  \
# 0              100.0                               96
# 1               26.0                               25
# 2               52.0                               51
# 3               59.0                               59
# 4               16.0                               16
#
#   Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                100
# 1                                                 26
# 2                                                 52
# 3                                                 59
# 4                                                 16
#
#   Average Medicare Allowed Amount Average Submitted Charge Amount  \
# 0                       73.398800                      325.780000
# 1                      100.080000                      449.000000
# 2                      136.380000                      614.000000
# 3                      190.363729                      755.932203
# 4                      101.680000                      462.812500
#
#   Average Medicare Payment Amount  Average Medicare Standardized Amount
# 0                       56.827200                             57.492400
# 1                       78.460000                             79.306154
# 2                      102.807692                            103.895385
# 3                      141.293559                            142.865763
# 4                       79.710000                             80.750000
#
# [5 rows x 26 columns]

# %%
payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   National Provider Identifier                              1000 non-null   int64
#  1   Last Name/Organization Name of the Provider               1000 non-null   object
#  2   First Name of the Provider                                976 non-null    object
#  3   Middle Initial of the Provider                            658 non-null    object
#  4   Credentials of the Provider                               936 non-null    object
#  5   Gender of the Provider                                    976 non-null    object
#  6   Entity Type of the Provider                               1000 non-null   object
#  7   Street Address 1 of the Provider                          1000 non-null   object
#  8   Street Address 2 of the Provider                          472 non-null    object
#  9   City of the Provider                                      1000 non-null   object
#  10  Zip Code of the Provider                                  1000 non-null   int64
#  11  State Code of the Provider                                1000 non-null   object
#  12  Country Code of the Provider                              1000 non-null   object
#  13  Provider Type                                             1000 non-null   object
#  14  Medicare Participation Indicator                          1000 non-null   object
#  15  Place of Service                                          1000 non-null   object
#  16  HCPCS Code                                                1000 non-null   object
#  17  HCPCS Description                                         1000 non-null   object
#  18  HCPCS Drug Indicator                                      1000 non-null   object
#  19  Number of Services                                        1000 non-null   float64
#  20  Number of Medicare Beneficiaries                          1000 non-null   int64
#  21  Number of Distinct Medicare Beneficiary/Per Day Services  1000 non-null   int64
#  22  Average Medicare Allowed Amount                           1000 non-null   float64
#  23  Average Submitted Charge Amount                           1000 non-null   float64
#  24  Average Medicare Payment Amount                           1000 non-null   float64
#  25  Average Medicare Standardized Amount                      1000 non-null   float64
# dtypes: float64(5), int64(4), object(17)
# memory usage: 203.2+ KB

# %% [markdown]
# #### What if you only want to gather the observations where HCPCS = 99213?

# %%
# %%time

HCPCS_rows =[]
for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv', 
                         chunksize = 1000):
    HCPCS_rows.append(chunk[chunk['HCPCS Code'] == '99213']) 
               
                
hcpcs_pay_99213 = pd.concat(HCPCS_rows, ignore_index=True)
# Out:
# CPU times: user 1min 40s, sys: 14.8 s, total: 1min 55s
# Wall time: 1min 56s

# %%
print(hcpcs_pay_99213.shape)
hcpcs_pay_99213.head()
# Out:
# (457843, 26)
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000142                                      KHALIL
# 1                    1003000423                                     VELOTTA
# 2                    1003000480                                   ROTHCHILD
# 3                    1003000522                                     WEIGAND
# 4                    1003000530                                    SEMONCHE
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                     RASHID                            NaN
# 1                   JENNIFER                              A
# 2                      KEVIN                              B
# 3                  FREDERICK                              J
# 4                     AMANDA                              M
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# 1                        M.D.                      F
# 2                          MD                      M
# 3                          MD                      M
# 4                          DO                      F
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I       4126 N HOLLAND SYLVANIA RD
# 1                           I                 11100 EUCLID AVE
# 2                           I                 12605 E 16TH AVE
# 3                           I                  1565 SAXON BLVD
# 4                           I                    1021 PARK AVE
#
#   Street Address 2 of the Provider City of the Provider  ... HCPCS Code  \
# 0                        SUITE 220               TOLEDO  ...      99213
# 1                              NaN            CLEVELAND  ...      99213
# 2                              NaN               AURORA  ...      99213
# 3                        SUITE 102              DELTONA  ...      99213
# 4                        SUITE 203           QUAKERTOWN  ...      99213
#
#                                    HCPCS Description HCPCS Drug Indicator  \
# 0  Established patient office or other outpatient...                    N
# 1  Established patient office or other outpatient...                    N
# 2  Established patient office or other outpatient...                    N
# 3  Established patient office or other outpatient...                    N
# 4  Established patient office or other outpatient...                    N
#
#   Number of Services Number of Medicare Beneficiaries  \
# 0              129.0                               89
# 1               21.0                               16
# 2               25.0                               23
# 3              360.0                              210
# 4              112.0                               96
#
#   Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                129
# 1                                                 21
# 2                                                 25
# 3                                                360
# 4                                                112
#
#   Average Medicare Allowed Amount Average Submitted Charge Amount  \
# 0                           70.93                           109.0
# 1                           70.93                            90.0
# 2                           52.06                           200.6
# 3                           73.17                           219.0
# 4                           78.47                           120.0
#
#   Average Medicare Payment Amount  Average Medicare Standardized Amount
# 0                       50.868062                             53.268372
# 1                       49.309524                             52.720000
# 2                       34.876800                             36.062800
# 3                       48.301222                             49.178417
# 4                       50.076607                             47.592679
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Let's keep the following columns:
# - National Provider Identifier  --                              1000 non-null int64
# - Last Name/Organization Name of the Provider --                1000 non-null object
# - First Name of the Provider  --                                976 non-null object
# - Credentials of the Provider  --                               936 non-null object
# - Entity Type of the Provider  --                               1000 non-null object
# - Street Address 1 of the Provider --                           1000 non-null object
# - City of the Provider --                                       1000 non-null object
# - Zip Code of the Provider --                                   1000 non-null int64
# - State Code of the Provider --                                 1000 non-null object
# - Country Code of the Provider --                              1000 non-null object
# - Provider Type --                                              1000 non-null object
# - Medicare Participation Indicator --                           1000 non-null object
# - Place of Service --                                           1000 non-null object
# - HCPCS Code --                                                 1000 non-null object
# - HCPCS Description --                                          1000 non-null object
# - HCPCS Drug Indicator --                                       1000 non-null object
# - Number of Services --                                         1000 non-null float64
# - Number of Medicare Beneficiaries --                           1000 non-null int64
# - Number of Distinct Medicare Beneficiary/Per Day Services --   1000 non-null int64
# - Average Medicare Allowed Amount --                            1000 non-null float64
# - Average Submitted Charge Amount --                            1000 non-null float64
# - Average Medicare Payment Amount --                            1000 non-null float64
# - Average Medicare Standardized Amount --                       1000 non-null float64

# %% [markdown]
# #### Is there anything we can convert from an object? Columns we can drop?
#  - Nothing convertible, but we'll drop 3 columns

# %%
hcpcs_pay_99213 = hcpcs_pay_99213.drop(columns = ['Middle Initial of the Provider', 
                                                  'Gender of the Provider',
                                                  'Street Address 2 of the Provider'])

# %%
hcpcs_pay_99213.to_pickle("../class_data/hcpcs_pay_99213.pkl")

# %%
# %%time

outpatient_docs_df = pd.read_pickle("../class_data/hcpcs_pay_99213.pkl")
# Out:
# CPU times: user 441 ms, sys: 146 ms, total: 588 ms
# Wall time: 589 ms

# %%
print(outpatient_docs.shape)
outpatient_docs.head()
# Out:
# (457843, 23)
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000142                                      KHALIL
# 1                    1003000423                                     VELOTTA
# 2                    1003000480                                   ROTHCHILD
# 3                    1003000522                                     WEIGAND
# 4                    1003000530                                    SEMONCHE
#
#   First Name of the Provider Credentials of the Provider  \
# 0                     RASHID                        M.D.
# 1                   JENNIFER                        M.D.
# 2                      KEVIN                          MD
# 3                  FREDERICK                          MD
# 4                     AMANDA                          DO
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           I       4126 N HOLLAND SYLVANIA RD
# 1                           I                 11100 EUCLID AVE
# 2                           I                 12605 E 16TH AVE
# 3                           I                  1565 SAXON BLVD
# 4                           I                    1021 PARK AVE
#
#   City of the Provider Zip Code of the Provider State Code of the Provider  \
# 0               TOLEDO                436233536                         OH
# 1            CLEVELAND                441061716                         OH
# 2               AURORA                800452545                         CO
# 3              DELTONA                327255876                         FL
# 4           QUAKERTOWN                    18951                         PA
#
#   Country Code of the Provider  ... HCPCS Code  \
# 0                           US  ...      99213
# 1                           US  ...      99213
# 2                           US  ...      99213
# 3                           US  ...      99213
# 4                           US  ...      99213
#
#                                    HCPCS Description HCPCS Drug Indicator  \
# 0  Established patient office or other outpatient...                    N
# 1  Established patient office or other outpatient...                    N
# 2  Established patient office or other outpatient...                    N
# 3  Established patient office or other outpatient...                    N
# 4  Established patient office or other outpatient...                    N
#
#   Number of Services Number of Medicare Beneficiaries  \
# 0              129.0                               89
# 1               21.0                               16
# 2               25.0                               23
# 3              360.0                              210
# 4              112.0                               96
#
#   Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                129
# 1                                                 21
# 2                                                 25
# 3                                                360
# 4                                                112
#
#    Average Medicare Allowed Amount  Average Submitted Charge Amount  \
# 0                            70.93                            109.0
# 1                            70.93                             90.0
# 2                            52.06                            200.6
# 3                            73.17                            219.0
# 4                            78.47                            120.0
#
#    Average Medicare Payment Amount  Average Medicare Standardized Amount
# 0                        50.868062                             53.268372
# 1                        49.309524                             52.720000
# 2                        34.876800                             36.062800
# 3                        48.301222                             49.178417
# 4                        50.076607                             47.592679
#
# [5 rows x 23 columns]
